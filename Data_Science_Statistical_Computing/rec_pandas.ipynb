# %% [markdown]
# <a href="https://colab.research.google.com/github/josekaneto/2ESR-Engenharia-de-Software/blob/main/Data_Science_Statistical_Computing/rec_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

ex26 = pd.read_csv('dataset_026.csv')
ex27 = pd.read_csv('dataset_027.csv')
ex28 = pd.read_csv('dataset_028.csv')
ex29 = pd.read_csv('dataset_029.csv')
ex30 = pd.read_csv('dataset_030.csv')
ex31 = pd.read_csv('dataset_031.csv')
ex32 = pd.read_csv('dataset_032.csv')
ex33 = pd.read_csv('dataset_033.csv')
ex34 = pd.read_csv('dataset_034.csv')
ex35 = pd.read_csv('dataset_035.csv')
ex36 = pd.read_csv('dataset_036.csv')
ex37 = pd.read_csv('dataset_037.csv')
ex38 = pd.read_csv('dataset_038.csv')
ex39 = pd.read_csv('dataset_039.csv')
ex40 = pd.read_csv('dataset_040.csv')
ex41 = pd.read_csv('dataset_041.csv')
ex42 = pd.read_csv('dataset_042.csv')
ex43 = pd.read_csv('dataset_043.csv')
ex44 = pd.read_csv('dataset_044.csv')
ex45 = pd.read_csv('dataset_045.csv')
ex46 = pd.read_csv('dataset_046.csv')
ex47 = pd.read_csv('dataset_047.csv')
ex48 = pd.read_csv('dataset_048.csv')
ex49 = pd.read_csv('dataset_049.csv')
ex50 = pd.read_csv('dataset_050.csv')

# %%
# ex26

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.


# EX 01

primeiro = ex26[(ex26['Nota'] > 8) & (ex26['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex26[(ex26['Entrega_no_prazo'] == 'SIM') & (ex26['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota_media_por_turma = ex26.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota_media_por_turma.max()))
print(terceiro)

# EX 04

idx_maior_presenca = ex26['Presenca_%'].idxmax()
nota_do_registro_maior_presenca = ex26.loc[idx_maior_presenca, 'Nota']

if pd.isna(nota_do_registro_maior_presenca):
    nota_do_registro_maior_presenca = 0

quarto = int(nota_do_registro_maior_presenca)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 3
# 28
# 5
# 9
# A soma das notas é: 45

# %%
#ex 27

# Calcule e guarde:
# 1) Quantos indivíduos têm idade acima de 70 anos E peso (em gramas) abaixo de 70000.
# 2) Quantos indivíduos são do sexo masculino, desconsiderando registros cujo nome esteja ausente.
# 3) Entre os indivíduos do sexo feminino, encontre o de maior altura e guarde o IMC desse indivíduo.
# 4) Quantas linhas do arquivo estão totalmente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex27[(ex27['Idade'] > 70) & ((ex27['Peso_kg'] * 1000) < 70000)].shape[0]
print(primeiro)

# 2)
segundo = ex27[(ex27['Sexo'] == 'M') & (ex27['Paciente'].notna())].shape[0]
print(segundo)

# 3)
feminino = ex27[ex27['Sexo'] == 'F']
idx = feminino['Alt_cm'].idxmax()
terceiro = int(feminino.loc[idx, 'IMC'])
print(terceiro)

# 4)
quarto = ex27.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 4
# 17
# 36
# 18
# A soma das notas é: 75

# %%
# ex28

# Calcule e guarde:
# 1) Quantas compras têm valor acima de 500 E prazo de entrega maior que 10 dias.
# 2) Entre as compras com cupom, desconsidere registros sem cidade e conte quantas são.
# 3) Descubra qual tipo de produto tem o maior valor médio de compra (ignore valores ausentes). Guarde esse maior valor médio, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex28[(ex28['Valor_R$'] > 500) & (ex28['Entrega_dias'] > 10)].shape[0]
print(primeiro)

# 2)
segundo = ex28[(ex28['Cupom'] == "SIM") & (ex28['Cidade'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex28.groupby('Categoria')['Valor_R$'].mean().max()))
print(terceiro)

# 4)
quarto = ex28.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 37
# 49
# 711
# 71
# A soma das notas é: 868

# %%
# ex29

# Calcule e guarde:
# 1) Quantos indivíduos têm idade acima de 70 anos E peso (em gramas) abaixo de 70000.
# 2) Quantos indivíduos são do sexo masculino, desconsiderando registros cujo nome esteja ausente.
# 3) Entre os indivíduos do sexo feminino, encontre o de maior altura e guarde o IMC desse indivíduo.
# 4) Quantas linhas do arquivo estão totalmente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex29[(ex29['Idade'] > 70) & ((ex29['Peso_kg'] * 1000) < 70000)].shape[0]
print(primeiro)

# 2)
segundo = ex29[(ex29['Sexo'] == 'M') & (ex29['Paciente'].notna())].shape[0]
print(segundo)

# 3)
feminino = ex29[ex29['Sexo'] == 'F']
idx = feminino['Alt_cm'].idxmax()
terceiro = int(feminino.loc[idx, 'IMC'])
print(terceiro)

# 4)
quarto = ex29.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 5
# 23
# 36
# 26
# A soma das notas é: 90

# %%
# ex 30

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex30[(ex30['Nota'] > 8) & (ex30['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex30[(ex30['Entrega_no_prazo'] == 'SIM') & (ex30['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota_media_por_turma = ex30.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota_media_por_turma.max()))
print(terceiro)

# EX 04

presenca = ex30['Presenca_%'].idxmax()
nota = ex30.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0


quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 3
# 27
# 5
# 2
# A soma das notas é: 37

# %%
# ex 31

# Calcule e guarde:
# 1) Quantas corridas têm atraso acima de 15 minutos E preço abaixo de 25.
# 2) Quantas corridas foram pagas por Pix, desconsiderando registros sem região.
# 3) Encontre a corrida com maior distância (desconsidere distâncias ausentes) e guarde o preço dessa corrida (se o preço estiver ausente, use 0). Arredonde esse preço para o inteiro mais próximo.
# 4) Por região, calcule o atraso médio (ignore atrasos ausentes). Guarde o maior atraso médio, arredondado para inteiro.

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex31[(ex31['Atraso_min'] > 15) & (ex31['Preco_R$'] < 25)].shape[0]
print(primeiro)

# 2)
segundo = ex31[(ex31['Pagamento'] == 'Pix') & (ex31['Regiao'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex31.loc[ex31['Dist_km'].idxmax(), 'Preco_R$']))

if pd.isna(terceiro):
  terceiro = 0

print(terceiro)

# 4)
quarto = int(round(ex31.groupby('Regiao')['Atraso_min'].mean().max()))
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 4
# 26
# 140
# 26
# A soma das notas é: 196

# %%
# ex 32

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex32[(ex32['Nota'] > 8) & (ex32['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex32[(ex32['Entrega_no_prazo'] == 'SIM') & (ex32['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota = ex32.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota.max()))
print(terceiro)

# EX 04

presenca = ex32['Presenca_%'].idxmax()
nota = ex32.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0

quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 5
# 36
# 6
# 2
# A soma das notas é: 49

# %%
# ex 33

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex33[(ex33['Nota'] > 8) & (ex33['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex33[(ex33['Entrega_no_prazo'] == 'SIM') & (ex33['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota = ex33.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota.max()))
print(terceiro)

# EX 04

presenca = ex33['Presenca_%'].idxmax()
nota = ex33.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0

quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 6
# 35
# 6
# 1
# A soma das notas é: 48

# %%
# ex34

# Calcule e guarde:
# 1) Quantos atendimentos têm severidade alta E tempo acima de 60 minutos.
# 2) Quantos atendimentos não estouraram o SLA, desconsiderando registros sem agente.
# 3) Para cada canal, calcule o tempo médio de atendimento (ignore tempos ausentes). Guarde o maior desses tempos médios, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex34[(ex34['Severidade'] == 'Alta') & (ex34['Tempo_min'] > 60)].shape[0]
print(primeiro)

# 2)
segundo = ex34[(ex34['SLA_ok'] == 'SIM') & (ex34['Agente'].notna())].shape[0]
print(segundo)

# 3)
tempo = ex34.groupby('Canal')['Tempo_min'].mean()
terceiro = int(round(tempo.max()))
print(terceiro)

# 4)
quarto = ex34.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(soma)
# Out:
# 13
# 30
# 120
# 45
# 208

# %%
# ex 35

# Calcule e guarde:
# 1) Quantas corridas têm atraso acima de 15 minutos E preço abaixo de 25.
# 2) Quantas corridas foram pagas por Pix, desconsiderando registros sem região.
# 3) Encontre a corrida com maior distância (desconsidere distâncias ausentes) e guarde o preço dessa corrida (se o preço estiver ausente, use 0). Arredonde esse preço para o inteiro mais próximo.
# 4) Por região, calcule o atraso médio (ignore atrasos ausentes). Guarde o maior atraso médio, arredondado para inteiro.

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex35[(ex35['Atraso_min'] > 15) & (ex35['Preco_R$'] < 25)].shape[0]
print(primeiro)

# 2)
segundo = ex35[(ex35['Pagamento'] == 'Pix') & (ex35['Regiao'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex35.loc[ex35['Dist_km'].idxmax(), 'Preco_R$']))

if pd.isna(terceiro):
  terceiro = 0

print(terceiro)

# 4)
quarto = int(round(ex35.groupby('Regiao')['Atraso_min'].mean().max()))
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 3
# 34
# 74
# 25
# A soma das notas é: 136

# %%
# ex 36

# Calcule e guarde:
# 1) Quantos atendimentos têm severidade alta E tempo acima de 60 minutos.
# 2) Quantos atendimentos não estouraram o SLA, desconsiderando registros sem agente.
# 3) Para cada canal, calcule o tempo médio de atendimento (ignore tempos ausentes). Guarde o maior desses tempos médios, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex36[(ex36['Severidade'] == 'Alta') & (ex36['Tempo_min'] > 60)].shape[0]
print(primeiro)

# 2)
segundo = ex36[(ex36['SLA_ok'] == 'SIM') & (ex36['Agente'].notna())].shape[0]
print(segundo)

# 3)
tempo = ex36.groupby('Canal')['Tempo_min'].mean()
terceiro = int(round(tempo.max()))
print(terceiro)

# 4)
quarto = ex36.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(soma)
# Out:
# 11
# 31
# 108
# 39
# 189

# %%
# ex 37

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex37[(ex37['Nota'] > 8) & (ex37['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex37[(ex37['Entrega_no_prazo'] == 'SIM') & (ex37['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota = ex37.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota.max()))
print(terceiro)

# EX 04

presenca = ex37['Presenca_%'].idxmax()
nota = ex37.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0

quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 2
# 32
# 6
# 7
# A soma das notas é: 47

# %%
# ex 38

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex38[(ex38['Nota'] > 8) & (ex38['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex38[(ex38['Entrega_no_prazo'] == 'SIM') & (ex38['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota = ex38.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota.max()))
print(terceiro)

# EX 04

presenca = ex38['Presenca_%'].idxmax()
nota = ex38.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0

quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 1
# 38
# 5
# 4
# A soma das notas é: 48

# %%
# ex 39

# Calcule e guarde:
# 1) Quantas compras têm valor acima de 500 E prazo de entrega maior que 10 dias.
# 2) Entre as compras com cupom, desconsidere registros sem cidade e conte quantas são.
# 3) Descubra qual tipo de produto tem o maior valor médio de compra (ignore valores ausentes). Guarde esse maior valor médio, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex39[(ex39['Valor_R$'] > 500) & (ex39['Entrega_dias'] > 10)].shape[0]
print(primeiro)

# 2)
segundo = ex39[(ex39['Cupom'] == "SIM") & (ex39['Cidade'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex39.groupby('Categoria')['Valor_R$'].mean().max()))
print(terceiro)

# 4)
quarto = ex39.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 43
# 55
# 796
# 83
# A soma das notas é: 977

# %%
# ex 40

# Calcule e guarde:
# 1) Quantas corridas têm atraso acima de 15 minutos E preço abaixo de 25.
# 2) Quantas corridas foram pagas por Pix, desconsiderando registros sem região.
# 3) Encontre a corrida com maior distância (desconsidere distâncias ausentes) e guarde o preço dessa corrida (se o preço estiver ausente, use 0). Arredonde esse preço para o inteiro mais próximo.
# 4) Por região, calcule o atraso médio (ignore atrasos ausentes). Guarde o maior atraso médio, arredondado para inteiro.

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex40[(ex40['Atraso_min'] > 15) & (ex40['Preco_R$'] < 25)].shape[0]
print(primeiro)

# 2)
segundo = ex40[(ex40['Pagamento'] == 'Pix') & (ex40['Regiao'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex40.loc[ex40['Dist_km'].idxmax(), 'Preco_R$']))

if pd.isna(terceiro):
  terceiro = 0

print(terceiro)

# 4)
quarto = int(round(ex40.groupby('Regiao')['Atraso_min'].mean().max()))
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 10
# 46
# 10
# 23
# A soma das notas é: 89

# %%
# ex 41

# Calcule e guarde:
# 1) Quantos indivíduos têm idade acima de 70 anos E peso (em gramas) abaixo de 70000.
# 2) Quantos indivíduos são do sexo masculino, desconsiderando registros cujo nome esteja ausente.
# 3) Entre os indivíduos do sexo feminino, encontre o de maior altura e guarde o IMC desse indivíduo.
# 4) Quantas linhas do arquivo estão totalmente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex41[(ex41['Idade'] > 70) & ((ex41['Peso_kg'] * 1000) < 70000)].shape[0]
print(primeiro)

# 2)
segundo = ex41[(ex41['Sexo'] == 'M') & (ex41['Paciente'].notna())].shape[0]
print(segundo)

# 3)
feminino = ex41[ex41['Sexo'] == 'F']
idx = feminino['Alt_cm'].idxmax()
terceiro = int(feminino.loc[idx, 'IMC'])
print(terceiro)

# 4)
quarto = ex41.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 6
# 33
# 36
# 40
# A soma das notas é: 115

# %%
# ex 42

# Calcule e guarde:
# 1) Quantos registros têm nota acima de 8 E presença acima de 85.
# 2) Quantos registros indicam entrega no prazo, desconsiderando registros sem nome do aluno.
# 3) Para cada turma, calcule a nota média (ignore notas ausentes). Guarde a maior dessas médias, arredondada para inteiro.
# 4) Encontre o registro com maior presença (ignore presenças ausentes) e guarde a nota desse registro (se a nota estiver ausente, use 0). Arredonde para inteiro.

# Some os quatro valores. Esse total é a resposta.

# EX 01

primeiro = ex42[(ex42['Nota'] > 8) & (ex42['Presenca_%'] > 85)].shape[0]
print(primeiro)

# EX 02

segundo = ex42[(ex42['Entrega_no_prazo'] == 'SIM') & (ex42['Aluno'].notna())].shape[0]
print(segundo)

# EX 03

nota = ex42.groupby('Turma')['Nota'].mean()
terceiro = int(round(nota.max()))
print(terceiro)

# EX 04

presenca = ex42['Presenca_%'].idxmax()
nota = ex42.loc[presenca, 'Nota']

if pd.isna(nota):
    nota = 0

quarto = int(nota)

print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 1
# 35
# 6
# 2
# A soma das notas é: 44

# %%
# ex 43

# Calcule e guarde:
# 1) Quantas corridas têm atraso acima de 15 minutos E preço abaixo de 25.
# 2) Quantas corridas foram pagas por Pix, desconsiderando registros sem região.
# 3) Encontre a corrida com maior distância (desconsidere distâncias ausentes) e guarde o preço dessa corrida (se o preço estiver ausente, use 0). Arredonde esse preço para o inteiro mais próximo.
# 4) Por região, calcule o atraso médio (ignore atrasos ausentes). Guarde o maior atraso médio, arredondado para inteiro.

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex43[(ex43['Atraso_min'] > 15) & (ex43['Preco_R$'] < 25)].shape[0]
print(primeiro)

# 2)
segundo = ex43[(ex43['Pagamento'] == 'Pix') & (ex43['Regiao'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex43.loc[ex43['Dist_km'].idxmax(), 'Preco_R$']))

if pd.isna(terceiro):
  terceiro = 0

print(terceiro)

# 4)
quarto = int(round(ex43.groupby('Regiao')['Atraso_min'].mean().max()))
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 7
# 35
# 83
# 22
# A soma das notas é: 147

# %%
# ex 44

# Calcule e guarde:
# 1) Quantos atendimentos têm severidade alta E tempo acima de 60 minutos.
# 2) Quantos atendimentos não estouraram o SLA, desconsiderando registros sem agente.
# 3) Para cada canal, calcule o tempo médio de atendimento (ignore tempos ausentes). Guarde o maior desses tempos médios, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex44[(ex44['Severidade'] == 'Alta') & (ex44['Tempo_min'] > 60)].shape[0]
print(primeiro)

# 2)
segundo = ex44[(ex44['SLA_ok'] == 'SIM') & (ex44['Agente'].notna())].shape[0]
print(segundo)

# 3)
tempo = ex44.groupby('Canal')['Tempo_min'].mean()
terceiro = int(round(tempo.max()))
print(terceiro)

# 4)
quarto = ex44.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(soma)
# Out:
# 14
# 32
# 89
# 45
# 180

# %%
# ex 45

# Calcule e guarde:
# 1) Quantos atendimentos têm severidade alta E tempo acima de 60 minutos.
# 2) Quantos atendimentos não estouraram o SLA, desconsiderando registros sem agente.
# 3) Para cada canal, calcule o tempo médio de atendimento (ignore tempos ausentes). Guarde o maior desses tempos médios, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex45[(ex45['Severidade'] == 'Alta') & (ex45['Tempo_min'] > 60)].shape[0]
print(primeiro)

# 2)
segundo = ex45[(ex45['SLA_ok'] == 'SIM') & (ex45['Agente'].notna())].shape[0]
print(segundo)

# 3)
tempo = ex45.groupby('Canal')['Tempo_min'].mean()
terceiro = int(round(tempo.max()))
print(terceiro)

# 4)
quarto = ex45.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(soma)
# Out:
# 10
# 23
# 94
# 31
# 158

# %%
# ex 46

# Calcule e guarde:
# 1) Quantas compras têm valor acima de 500 E prazo de entrega maior que 10 dias.
# 2) Entre as compras com cupom, desconsidere registros sem cidade e conte quantas são.
# 3) Descubra qual tipo de produto tem o maior valor médio de compra (ignore valores ausentes). Guarde esse maior valor médio, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex46[(ex46['Valor_R$'] > 500) & (ex46['Entrega_dias'] > 10)].shape[0]
print(primeiro)

# 2)
segundo = ex46[(ex46['Cupom'] == 'SIM') & (ex46['Cidade'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex46.groupby('Categoria')['Valor_R$'].mean().max()))
print(terceiro)

# 4)
quarto = ex46.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 24
# 44
# 739
# 65
# A soma das notas é: 872

# %%
# ex 47

# Calcule e guarde:
# 1) Quantas compras têm valor acima de 500 E prazo de entrega maior que 10 dias.
# 2) Entre as compras com cupom, desconsidere registros sem cidade e conte quantas são.
# 3) Descubra qual tipo de produto tem o maior valor médio de compra (ignore valores ausentes). Guarde esse maior valor médio, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex47[(ex47['Valor_R$'] > 500) & (ex47['Entrega_dias'] > 10)].shape[0]
print(primeiro)

# 2)
segundo = ex47[(ex47['Cupom'] == "SIM") & (ex47['Cidade'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex47.groupby('Categoria')['Valor_R$'].mean().max()))
print(terceiro)

# 4)
quarto = ex47.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 23
# 38
# 680
# 53
# A soma das notas é: 794

# %%
# ex 48

# Calcule e guarde:
# 1) Quantos indivíduos têm idade acima de 70 anos E peso (em gramas) abaixo de 70000.
# 2) Quantos indivíduos são do sexo masculino, desconsiderando registros cujo nome esteja ausente.
# 3) Entre os indivíduos do sexo feminino, encontre o de maior altura e guarde o IMC desse indivíduo.
# 4) Quantas linhas do arquivo estão totalmente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex48[(ex48['Idade'] > 70) & ((ex48['Peso_kg'] * 1000) < 70000)].shape[0]
print(primeiro)

# 2)
segundo = ex48[(ex48['Sexo'] == 'M') & (ex48['Paciente'].notna())].shape[0]
print(segundo)

# 3)
feminino = ex48[ex48['Sexo'] == 'F']
idx = feminino['Alt_cm'].idxmax()
terceiro = int(feminino.loc[idx, 'IMC'])
print(terceiro)

# 4)
quarto = ex48.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(f"A soma das notas é: {soma}")
# Out:
# 6
# 27
# 39
# 31
# A soma das notas é: 103

# %%
# ex 49

# Calcule e guarde:
# 1) Quantos atendimentos têm severidade alta E tempo acima de 60 minutos.
# 2) Quantos atendimentos não estouraram o SLA, desconsiderando registros sem agente.
# 3) Para cada canal, calcule o tempo médio de atendimento (ignore tempos ausentes). Guarde o maior desses tempos médios, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex49[(ex49['Severidade'] == 'Alta') & (ex49['Tempo_min'] > 60)].shape[0]
print(primeiro)

# 2)
segundo = ex49[(ex49['SLA_ok'] == 'SIM') & (ex49['Agente'].notna())].shape[0]
print(segundo)

# 3)
tempo = ex49.groupby('Canal')['Tempo_min'].mean()
terceiro = int(round(tempo.max()))
print(terceiro)

# 4)
quarto = ex49.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto

print(soma)
# Out:
# 24
# 41
# 100
# 46
# 211

# %%
# ex 50

# Calcule e guarde:
# 1) Quantas compras têm valor acima de 500 E prazo de entrega maior que 10 dias.
# 2) Entre as compras com cupom, desconsidere registros sem cidade e conte quantas são.
# 3) Descubra qual tipo de produto tem o maior valor médio de compra (ignore valores ausentes). Guarde esse maior valor médio, arredondado para o inteiro mais próximo.
# 4) Quantas linhas estão completamente preenchidas (sem nenhum dado ausente).

# Some os quatro valores. Esse total é a resposta.

# 1)
primeiro = ex50[(ex50['Valor_R$'] > 500) & (ex50['Entrega_dias'] > 10)].shape[0]
print(primeiro)

# 2)
segundo = ex50[(ex50['Cupom'] == "SIM") & (ex50['Cidade'].notna())].shape[0]
print(segundo)

# 3)
terceiro = int(round(ex50.groupby('Categoria')['Valor_R$'].mean().max()))
print(terceiro)

# 4)
quarto = ex50.dropna().shape[0]
print(quarto)

soma = primeiro + segundo + terceiro + quarto
print(f"A soma das notas é: {soma}")
# Out:
# 32
# 51
# 637
# 76
# A soma das notas é: 796
